# %% [markdown]
# <a href="https://colab.research.google.com/github/gonzoreyes07/Estadistica/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Leemos el archivo con la librería pandas
df = pd.read_csv("Alumnos.csv", encoding="latin-1")

# Unimos nombre y apellido en una sola columna
df["Nombre Completo"] = df.iloc[:, 0] + " " + df.iloc[:, 1]

# Agregar columnas con datos aleatorios
np.random.seed(42)
df["Edad"] = np.random.randint(18, 26, size=len(df))
df["Calificación"] = np.random.normal(7.5, 1.0, size=len(df)).clip(0, 10)  # Calificación entre 0 y 10
df["Asistencia (%)"] = np.random.uniform(70, 100, size=len(df))

# Mostrar el DataFrame
print(df.head())

# 1. Histograma de distribución de edades
plt.figure(figsize=(8, 5))
plt.hist(df["Edad"], bins=8, color="green", edgecolor="black")
plt.xlabel("Edad")
plt.ylabel("Frecuencia")
plt.title("Distribución de edades de los alumnos")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# 2. Gráfico de barras de asistencia
plt.figure(figsize=(10, 6))
plt.bar(df["Nombre Completo"], df["Asistencia (%)"], color="lightcoral")
plt.xlabel("Alumnos")
plt.ylabel("Asistencia (%)")
plt.title("Porcentaje de Asistencia de los Alumnos")
plt.xticks(rotation=90)
plt.ylim(50, 100)  # Ajuste del rango de asistencia
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# 3. Diagrama de dispersión: Edad vs. Asistencia
plt.figure(figsize=(8, 5))
plt.scatter(df["Edad"], df["Asistencia (%)"], color="green", alpha=0.6)
plt.xlabel("Edad")
plt.ylabel("Asistencia (%)")
plt.title("Relación entre Edad y Asistencia")
plt.grid(True)
plt.show()

# 4. Gráfico de barras de Calificaciones
plt.figure(figsize=(10, 6))
plt.bar(df["Nombre Completo"], df["Calificación"], color="blue")
plt.xlabel("Alumnos")
plt.ylabel("Calificación")
plt.title("Calificaciones de los Alumnos")
plt.xticks(rotation=90)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# 5. Estadísticas generales del DataFrame
print(df.describe())
# Out:
#       Nombre  Apellido   Nombre Completo  Edad  Calificación  Asistencia (%)
# 0    Abigail  Saavedra  Abigail Saavedra    24      8.962378       76.238250
# 1    Adanely  Espinosa  Adanely Espinosa    21      9.038715       87.031010
# 2  Alexander    Cortez  Alexander Cortez    22      5.060894       70.939399
# 3      Anali    Valdez      Anali Valdez    24      8.103441       95.268543
# 4     Andrea     Reyes      Andrea Reyes    20      7.248956       83.492624
#             Edad  Calificación  Asistencia (%)
# count  27.000000     27.000000       27.000000
# mean   22.259259      7.557983       84.328358
# std     1.992150      0.948588        8.627186
# min    19.000000      5.060894       70.422395
# 25%    20.500000      7.111389       78.542310
# 50%    22.000000      7.470161       83.492624
# 75%    24.000000      8.134048       90.014594
# max    25.000000      9.080851       98.957659
